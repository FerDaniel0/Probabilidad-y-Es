# %% [markdown]
# <a href="https://colab.research.google.com/github/FerDaniel0/Probabilidad-y-Es/blob/main/Unidad%201/Practica%204%20y%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad Y estadistica
# *Unidad 1*
#
# *Alumno Juan Daniel Simenta Mendoza*
#
# *Faciilitador Dr. Jose Gabriel Rodrigues Rivas*
#
# Problema 4

# %%
import random

# %%
edades = []
for i in range(100):
  numero_aleatorio = random.randint( 18, 70)
  edades.append(numero_aleatorio)

print(edades)
# Out:
# [52, 48, 51, 40, 69, 19, 66, 68, 25, 64, 22, 22, 22, 43, 28, 31, 27, 65, 70, 24, 60, 67, 32, 58, 55, 34, 58, 25, 18, 19, 24, 22, 28, 39, 22, 62, 33, 58, 28, 34, 45, 53, 28, 26, 55, 23, 46, 57, 50, 48, 40, 54, 65, 65, 18, 43, 64, 52, 19, 27, 46, 38, 25, 44, 26, 24, 57, 44, 65, 66, 62, 20, 47, 43, 22, 68, 70, 37, 65, 43, 49, 58, 26, 35, 38, 65, 39, 55, 65, 58, 18, 62, 44, 66, 22, 50, 52, 46, 45, 70]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns = ['Edad'])
df.head()
# Out:
#    Edad
# 0    52
# 1    48
# 2    51
# 3    40
# 4    69

# %%
tabla_frecuencias = df ['Edad'].value_counts().reset_index()
tabla_frecuencias.columns =['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

#imprimir la tabla
print("tabla de frecuencias")
tabla_frecuencias
# Out:
# tabla de frecuencias
#     Edad  Frecuencia
# 9     18           3
# 16    19           3
# 32    20           1
# 1     22           7
# 37    23           1
# 11    24           3
# 15    25           3
# 7     26           3
# 17    27           2
# 4     28           4
# 40    31           1
# 36    32           1
# 41    33           1
# 24    34           2
# 42    35           1
# 30    37           1
# 18    38           2
# 22    39           2
# 21    40           2
# 3     43           4
# 5     44           3
# 23    45           2
# 6     46           3
# 31    47           1
# 25    48           2
# 29    49           1
# 19    50           2
# 33    51           1
# 13    52           3
# 39    53           1
# 28    54           1
# 10    55           3
# 20    57           2
# 2     58           5
# 35    60           1
# 8     62           3
# 26    64           2
# 0     65           7
# 14    66           3
# 34    67           1
# 27    68           2
# 38    69           1
# 12    70           3

# %%
tabla_frecuencias['Frecuencia relativa'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia relativa
# 9     18           3                 0.03
# 16    19           3                 0.03
# 32    20           1                 0.01
# 1     22           7                 0.07
# 37    23           1                 0.01
# 11    24           3                 0.03
# 15    25           3                 0.03
# 7     26           3                 0.03
# 17    27           2                 0.02
# 4     28           4                 0.04
# 40    31           1                 0.01
# 36    32           1                 0.01
# 41    33           1                 0.01
# 24    34           2                 0.02
# 42    35           1                 0.01
# 30    37           1                 0.01
# 18    38           2                 0.02
# 22    39           2                 0.02
# 21    40           2                 0.02
# 3     43           4                 0.04
# 5     44           3                 0.03
# 23    45           2                 0.02
# 6     46           3                 0.03
# 31    47           1                 0.01
# 25    48           2                 0.02
# 29    49           1                 0.01
# 19    50           2                 0.02
# 33    51           1                 0.01
# 13    52           3                 0.03
# 39    53           1                 0.01
# 28    54           1                 0.01
# 10    55           3                 0.03
# 20    57           2                 0.02
# 2     58           5                 0.05
# 35    60           1                 0.01
# 8     62           3                 0.03
# 26    64           2                 0.02
# 0     65           7                 0.07
# 14    66           3                 0.03
# 34    67           1                 0.01
# 27    68           2                 0.02
# 38    69           1                 0.01
# 12    70           3                 0.03

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia relativa  Frec porcentual
# 9     18           3                 0.03              3.0
# 16    19           3                 0.03              3.0
# 32    20           1                 0.01              1.0
# 1     22           7                 0.07              7.0
# 37    23           1                 0.01              1.0
# 11    24           3                 0.03              3.0
# 15    25           3                 0.03              3.0
# 7     26           3                 0.03              3.0
# 17    27           2                 0.02              2.0
# 4     28           4                 0.04              4.0
# 40    31           1                 0.01              1.0
# 36    32           1                 0.01              1.0
# 41    33           1                 0.01              1.0
# 24    34           2                 0.02              2.0
# 42    35           1                 0.01              1.0
# 30    37           1                 0.01              1.0
# 18    38           2                 0.02              2.0
# 22    39           2                 0.02              2.0
# 21    40           2                 0.02              2.0
# 3     43           4                 0.04              4.0
# 5     44           3                 0.03              3.0
# 23    45           2                 0.02              2.0
# 6     46           3                 0.03              3.0
# 31    47           1                 0.01              1.0
# 25    48           2                 0.02              2.0
# 29    49           1                 0.01              1.0
# 19    50           2                 0.02              2.0
# 33    51           1                 0.01              1.0
# 13    52           3                 0.03              3.0
# 39    53           1                 0.01              1.0
# 28    54           1                 0.01              1.0
# 10    55           3                 0.03              3.0
# 20    57           2                 0.02              2.0
# 2     58           5                 0.05              5.0
# 35    60           1                 0.01              1.0
# 8     62           3                 0.03              3.0
# 26    64           2                 0.02              2.0
# 0     65           7                 0.07              7.0
# 14    66           3                 0.03              3.0
# 34    67           1                 0.01              1.0
# 27    68           2                 0.02              2.0
# 38    69           1                 0.01              1.0
# 12    70           3                 0.03              3.0

# %%
tabla_frecuencias['Frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia relativa  Frec porcentual  Frec acumulada
# 9     18           3                 0.03              3.0               3
# 16    19           3                 0.03              3.0               6
# 32    20           1                 0.01              1.0               7
# 1     22           7                 0.07              7.0              14
# 37    23           1                 0.01              1.0              15
# 11    24           3                 0.03              3.0              18
# 15    25           3                 0.03              3.0              21
# 7     26           3                 0.03              3.0              24
# 17    27           2                 0.02              2.0              26
# 4     28           4                 0.04              4.0              30
# 40    31           1                 0.01              1.0              31
# 36    32           1                 0.01              1.0              32
# 41    33           1                 0.01              1.0              33
# 24    34           2                 0.02              2.0              35
# 42    35           1                 0.01              1.0              36
# 30    37           1                 0.01              1.0              37
# 18    38           2                 0.02              2.0              39
# 22    39           2                 0.02              2.0              41
# 21    40           2                 0.02              2.0              43
# 3     43           4                 0.04              4.0              47
# 5     44           3                 0.03              3.0              50
# 23    45           2                 0.02              2.0              52
# 6     46           3                 0.03              3.0              55
# 31    47           1                 0.01              1.0              56
# 25    48           2                 0.02              2.0              58
# 29    49           1                 0.01              1.0              59
# 19    50           2                 0.02              2.0              61
# 33    51           1                 0.01              1.0              62
# 13    52           3                 0.03              3.0              65
# 39    53           1                 0.01              1.0              66
# 28    54           1                 0.01              1.0              67
# 10    55           3                 0.03              3.0              70
# 20    57           2                 0.02              2.0              72
# 2     58           5                 0.05              5.0              77
# 35    60           1                 0.01              1.0              78
# 8     62           3                 0.03              3.0              81
# 26    64           2                 0.02              2.0              83
# 0     65           7                 0.07              7.0              90
# 14    66           3                 0.03              3.0              93
# 34    67           1                 0.01              1.0              94
# 27    68           2                 0.02              2.0              96
# 38    69           1                 0.01              1.0              97
# 12    70           3                 0.03              3.0             100

# %% [markdown]
# # Regla de sturges
#
# 1.- Es una regla que sirve para calcular el número de clases o intervalos idóneos en los que que se debe dividir un conjunto de datos. 2.Establece que el número de clases es igual a uno más el logaritmo en base dos del número total de datos.
#
# ** * C= 1 + log²(N)* **
#
# Donde N es el tamaño de la muestra.

# %%
import math

# %%
print(edades)
# Out:
# [52, 48, 51, 40, 69, 19, 66, 68, 25, 64, 22, 22, 22, 43, 28, 31, 27, 65, 70, 24, 60, 67, 32, 58, 55, 34, 58, 25, 18, 19, 24, 22, 28, 39, 22, 62, 33, 58, 28, 34, 45, 53, 28, 26, 55, 23, 46, 57, 50, 48, 40, 54, 65, 65, 18, 43, 64, 52, 19, 27, 46, 38, 25, 44, 26, 24, 57, 44, 65, 66, 62, 20, 47, 43, 22, 68, 70, 37, 65, 43, 49, 58, 26, 35, 38, 65, 39, 55, 65, 58, 18, 62, 44, 66, 22, 50, 52, 46, 45, 70]

# %%
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     52
# 1     48
# 2     51
# 3     40
# 4     69
# ..   ...
# 95    50
# 96    52
# 97    46
# 98    45
# 99    70
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int( 1 + math.log2(100))
print("Valor de n = ", n , " \nNúmero de intervalos =", k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    21
# 1    (62.571, 70.0]    19
# 2  (47.714, 55.143]    14
# 3  (40.286, 47.714]    13
# 4  (25.429, 32.857]    11
# 5  (32.857, 40.286]    11
# 6  (55.143, 62.571]    11

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    21
# 4  (25.429, 32.857]    11
# 5  (32.857, 40.286]    11
# 3  (40.286, 47.714]    13
# 2  (47.714, 55.143]    14
# 6  (55.143, 62.571]    11
# 1    (62.571, 70.0]    19

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print("Tabla de frecuencias")
tabla_frecuencia
# Out:
# Tabla de frecuencias
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 0  (17.947, 25.429]    21      0.21       21.0       21         0.21
# 4  (25.429, 32.857]    11      0.11       11.0       32         0.32
# 5  (32.857, 40.286]    11      0.11       11.0       43         0.43
# 3  (40.286, 47.714]    13      0.13       13.0       56         0.56
# 2  (47.714, 55.143]    14      0.14       14.0       70         0.70
# 6  (55.143, 62.571]    11      0.11       11.0       81         0.81
# 1    (62.571, 70.0]    19      0.19       19.0      100         1.00
#
#    Frec Porc Ac
# 0          21.0
# 4          32.0
# 5          43.0
# 3          56.0
# 2          70.0
# 6          81.0
# 1         100.0

# %% [markdown]
# # Probabilidad Y estadistica
# *Unidad 1*
#
# *Alumno Juan Daniel Simenta Mendoza*
#
# *Faciilitador Dr. Jose Gabriel Rodrigues Rivas*
#
# Problema 5

# %% [markdown]
# # Diagrma De Cajas Y Bigotes

# %%
import matplotlib.pyplot as plt

# %%
edades2 = []
for i in range(100):
  numero_aleatorio = random.randint( 20, 87)
  edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [83, 35, 40, 67, 61, 64, 86, 36, 83, 84, 70, 20, 86, 83, 40, 22, 38, 52, 64, 54, 75, 68, 63, 84, 40, 82, 29, 24, 77, 41, 45, 75, 43, 85, 76, 44, 75, 47, 83, 64, 48, 26, 32, 73, 65, 85, 69, 39, 33, 85, 29, 22, 53, 36, 57, 22, 26, 20, 79, 52, 23, 74, 61, 37, 79, 36, 46, 31, 28, 38, 28, 24, 60, 43, 54, 25, 85, 27, 36, 31, 77, 48, 47, 25, 32, 25, 43, 40, 81, 66, 59, 84, 29, 28, 68, 59, 21, 74, 25, 84]

# %%
fig,(ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (9, 4))

bplot2 = ax1.boxplot(edades,
                     vert = True,
                     patch_artist = True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert = True,
                     patch_artist = True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig,(ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (9, 4))

bplot2 = ax1.boxplot(edades,
                     vert = True,
                     patch_artist = True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2,
                     vert = True,
                     patch_artist = True)
ax2.set_title('Edades Encuesta 2')
plt.show()
